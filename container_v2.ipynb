# %%
#from Protocole_complet import search_wiki_
#from ipynb.fs.full.Protocole_complet import search_wiki_
import glob
from ipynb.fs.full.scrap_on_google_v2 import advanced_scraper
from ipynb.fs.full.similarity_measure import compute_best_terms, compute_best_doc
# from ipynb.fs.full.applyBiotex import biotex_terms_extractor
# Out:
# The time recorded in the file is :  1628777344.7731392
# The time now  is :  1628777726.448533
# A total difference of 6.361256563663483 minutes
# It has been less than 15 minutes since the proxies were renewed, therefore sticking with the old proxies

# %%
# import session_info
# session_info.show()

# %%
#

# %% [markdown]
# # 1 - CHOIX DES TERMES EXPERTS

# %% [markdown]
# # 2 - Scrap Google data for thematic vocabulary concepts

# %% [markdown]
# # 3 - Final step to build thematic corpora

# %% [markdown]
# Build final thematic corpora by specifying an Spatial extent, and the thematic vocabulary concepts file

# %%
# # spatial_extent = '' # name of the corrsponding territory
# # extend_voc_concept = '' # extended vocabulary concept file
# # mgdb,mgcol = '','' db and collection name
# #########
# spatial_extent = 'montpellier'
# voc_concept = './voc_concept/agriculture.txt'
# # mgdb,mgcol = 'inventaire_medo', 'agriculture_demo' # parameters to be set initially
# #advanced_scraper(spatial_extent,voc_concept)
# advanced_scraper(spatial_extent,voc_concept)
# Out:
# Lecture de keywords.txt ...
#
# Début de la recherche de document concernant la ville de Montpellier
# Génération des requêtes
# Nouvelle requête : "Montpellier" AND exploitation?agricole
#
# URL : https://www.letudiant.fr/etudes/annuaire-enseignement-superieur/formation/formation-bp-responsable-d-exploitation-agricole-44613.html
#
# Document sauvegardé.
# Document web converti en texte brut.
# Texte nettoyé.
#
# Document inséré dans l'inventaire.
#
# INFO:collecteDeDonnees_12-08-21:Document inséré dans l'inventaire.
#
# URL : https://fr.jobted.com/emploi-exploitation-agricole-%C3%A0-montpellier-(34)
#
# INFO:collecteDeDonnees_12-08-21:URL : https://fr.jobted.com/emploi-exploitation-agricole-%C3%A0-montpellier-(34)
#
# Document sauvegardé.
# INFO:collecteDeDonnees_12-08-21:Document sauvegardé.
# Document web converti en texte brut.
# INFO:collecteDeDonnees_12-08-21:Document web converti en texte brut.
# Texte nettoyé.
#
# INFO:collecteDeDonnees_12-08-21:Texte nettoyé.
#
# ...

# %%
files_list = glob.glob("./voc_concept/*")
spatial_extent = 'montpellier'
for voc_concept in files_list:
    advanced_scraper(spatial_extent,voc_concept)
# Out:
# Création des dossier pour Montpellier
# Création du dossier Documents_SRC
#
# Lecture de keywords.txt ...
#
# Début de la recherche de document concernant la ville de Montpellier
# Génération des requêtes
# Nouvelle requête : "Montpellier" AND situation?hydrologique
#
# URL : http://www.occitanie.developpement-durable.gouv.fr/le-bulletin-de-situation-hydrologique-a24261.html
#
# Document sauvegardé.
# Erreur lors de la conversion en texte de la page web.
# Traceback (most recent call last):
#   File "/home/rodrique/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb", line 595, in sauvegarde_fichier_advanced
#     "        # On ajoute un espace devant chaque span, pour éviter\n",
#   File "/home/rodrique/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb", line 443, in convert_html_to_txt
#     "        @type  mot: String.\n",
# ...

# %%
# Out:
# ['./voc_concept/hydrologie.txt', './voc_concept/agriculture.txt', './voc_concept/urbanisation.txt']

# %%
######## TO DO
# 1) Convertir directement les fichier à partir des Urls, et non après sauvegarde dans SCR_
# 2) Supprimer la sauvegarde locale
# 3) extraire TNE des docs de type html 
#   * (utiliser htmldate--> https://htmldate.readthedocs.io/en/latest/)
#   * sauvegarde_fichier_advanced() à adapter pour ne plus avoir à sauvegarder les documents
# 4) ajouter la thématique en tant que variable dans chaque doc
#    * creation_dossier_resultat() -> retournera 'mots_cles', et 'thematique'
#    * thmetatique est obtenu en faisant une xtraction à partir du fichier voc_concept
#    * ajouter 'thematique' dans la fonction recherche_web_advanced() pour pouvoir créer la clé
#    * document['thematic'] = 'thematique'
######
# Out:
#   File "<ipython-input-9-a18ab5e61b2d>", line 9
#     * thmetatique est obtenu en faisant une xtraction à partir du fichier voc_concept
#     ^
# IndentationError: unexpected indent

# %%
# Click to view session information
# -----
# ipynb               NA
# pyforest            1.0.2
# session_info        1.0.0
# -----
# Click to view modules imported as dependencies
# OpenSSL                             19.1.0
# PIL                                 6.2.0
# PyPDF2                              1.26.0
# absl                                NA
# astunparse                          1.6.3
# attr                                20.2.0
# backcall                            0.2.0
# backports                           NA
# blis                                NA
# boto3                               1.9.232
# botocore                            1.12.232
# bottleneck                          1.3.2
# brotli                              NA
# bs4                                 4.9.3
# bson                                NA
# catalogue                           NA
# certifi                             2021.05.30
# cffi                                1.14.0
# chardet                             3.0.4
# colorama                            0.4.3
# cryptography                        3.1.1
# cymem                               NA
# cython_runtime                      NA
# dateutil                            2.8.1
# decorator                           4.4.2
# fe17a9cb4bdaf05853229027e5fef937    NA
# filelock                            3.0.12
# flatbuffers                         NA
# ftfy                                5.8
# gast                                NA
# google                              NA
# googlesearch                        NA
# h5py                                2.10.0
# html2text                           2019.8.11
# html5lib                            1.1
# idna                                2.10
# importlib_metadata                  1.7.0
# ipykernel                           4.8.2
# ipython_genutils                    0.2.0
# ipywidgets                          7.5.1
# jedi                                0.17.2
# jmespath                            0.10.0
# joblib                              0.11
# jsonschema                          3.2.0
# keras_preprocessing                 1.1.2
# lxml                                4.5.2
# magic                               NA
# mpl_toolkits                        NA
# murmurhash                          NA
# nltk                                3.5
# numpy                               1.20.3
# opt_einsum                          v3.3.0
# packaging                           20.4
# pandas                              1.1.3
# parso                               0.7.1
# pexpect                             4.8.0
# pickleshare                         0.7.5
# pkg_resources                       NA
# plac                                0.9.6
# plac_core                           NA
# plac_ext                            NA
# preshed                             NA
# prompt_toolkit                      3.0.7
# psutil                              5.7.2
# ptyprocess                          0.6.0
# pvectorc                            NA
# pygments                            2.7.1
# pymongo                             3.9.0
# pyrsistent                          NA
# pytz                                2021.1
# regex                               2.5.84
# requests                            2.25.1
# sacremoses                          0.0.41
# scipy                               1.5.2
# search_engine_scraper               NA
# sentence_transformers               0.3.7
# sentencepiece                       NA
# simplejson                          3.17.2
# six                                 1.16.0
# sklearn                             0.24.1
# socks                               1.7.1
# soupsieve                           2.0.1
# spacy                               2.3.5
# sphinxcontrib                       NA
# srsly                               NA
# storemagic                          NA
# swig_runtime_data4                  NA
# tblib                               1.7.0
# tensorboard                         2.4.1
# tensorflow                          2.4.1
# termcolor                           1.1.0
# thinc                               7.4.5
# tokenizers                          0.8.1.rc2
# torch                               1.4.0
# tornado                             6.0.4
# tqdm                                4.50.2
# traitlets                           5.0.4
# transformers                        3.3.1
# typing_extensions                   NA
# urllib3                             1.26.6
# wasabi                              NA
# wcwidth                             0.2.5
# webencodings                        0.5.1
# wrapt                               1.12.1
# yaml                                5.3.1
# zipp                                NA
# zmq                                 17.0.0
# zope                                NA
# -----
# IPython             7.18.1
# jupyter_client      6.1.7
# jupyter_core        4.6.3
# jupyterlab          2.2.6
# notebook            6.1.4
# -----
# Python 3.7.7 (default, Mar 23 2020, 22:36:06) [GCC 7.3.0]
# Linux-4.4.0-210-generic-x86_64-with-debian-stretch-sid
# -----
# Session information updated at 2021-08-11 10:25

# %%
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fr-core-news-sm 2.3.0 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.1.0 which is incompatible.
# fr-core-news-md 3.0.0 requires spacy<3.1.0,>=3.0.0, but you have spacy 3.1.0 which is incompatible.
# en-core-web-sm 2.3.1 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.1.0 which is incompatible.
