# %%
#from Protocole_complet import search_wiki_
#from ipynb.fs.full.Protocole_complet import search_wiki_
from ipynb.fs.full.scrap_on_google_v2 import advanced_scraper
from ipynb.fs.full.similarity_measure import compute_best_terms, compute_best_doc
# from ipynb.fs.full.applyBiotex import biotex_terms_extractor
# Out:
# The time recorded in the file is :  1628510626.7888317
# The time now  is :  1628510645.7366867
# A total difference of 0.31579758326212565 minutes
# It has been less than 15 minutes since the proxies were renewed, therefore sticking with the old proxies

# %% [markdown]
# # 1 - CHOIX DES TERMES EXPERTS

# %% [markdown]
# # 2 - Scrap Google data for thematic vocabulary concepts

# %% [markdown]
# # 3 - Final step to build thematic corpora

# %% [markdown]
# Build final thematic corpora by specifying an Spatial extent, and the thematic vocabulary concepts file

# %%
# spatial_extent = '' # name of the corrsponding territory
# extend_voc_concept = '' # extended vocabulary concept file
# mgdb,mgcol = '','' db and collection name
#########
spatial_extent = 'montpellier'
voc_concept = './voc_concept/agriculture.txt'
# mgdb,mgcol = 'inventaire_medo', 'agriculture_demo' # parameters to be set initially
#advanced_scraper(spatial_extent,voc_concept)
advanced_scraper(spatial_extent,voc_concept)
# Out:
# Lecture de keywords.txt ...
#
# Début de la recherche de document concernant la ville de Montpellier
# Génération des requêtes
# Nouvelle requête : "Montpellier" AND agricole?perdu
#
# URL : https://www.cairn.info/revue-espaces-et-societes-2014-3-page-49.htm
#
# Erreur pour l'URL : https://www.cairn.info/revue-espaces-et-societes-2014-3-page-49.htm
#
# URL : https://www.montpellier3m.fr/sites/default/files/downloads/files/mmm-scot-agroeco-bd_3.pdf
# HTTP Error 403: Forbidden
# Document sauvegardé.
# Document PDF converti en texte brut.
# Texte nettoyé.
#
# Document inséré dans l'inventaire.
#
# INFO:collecteDeDonnees_09-08-21:Document inséré dans l'inventaire.
#
# URL : http://www.occitanie.developpement-durable.gouv.fr/IMG/pdf/Observatoire_des_espaces_agricoles_et_forestiers-dep-herault-plaine_de_montpellier_et_lunel__cle776816.pdf
#
# INFO:collecteDeDonnees_09-08-21:URL : http://www.occitanie.developpement-durable.gouv.fr/IMG/pdf/Observatoire_des_espaces_agricoles_et_forestiers-dep-herault-plaine_de_montpellier_et_lunel__cle776816.pdf
#
# Le document existe déjà.
#
# INFO:collecteDeDonnees_09-08-21:Le document existe déjà.
#
# URL : https://www.ac-montpellier.fr/cid87196/diplomes-attestations-reussite-releves-notes.html
#
# INFO:collecteDeDonnees_09-08-21:URL : https://www.ac-montpellier.fr/cid87196/diplomes-attestations-reussite-releves-notes.html
#
# Document sauvegardé.
# INFO:collecteDeDonnees_09-08-21:Document sauvegardé.
# Document web converti en texte brut.
# INFO:collecteDeDonnees_09-08-21:Document web converti en texte brut.
# Texte nettoyé.
#
# INFO:collecteDeDonnees_09-08-21:Texte nettoyé.
#
# Document inséré dans l'inventaire.
#
# INFO:collecteDeDonnees_09-08-21:Document inséré dans l'inventaire.
#
# URL : https://france3-regions.francetvinfo.fr/occitanie/herault/montpellier/ce-milliard-d-euros-ne-suffira-pas-la-reaction-dans-l-herault-au-plan-gel-du-gouvernement-pour-l-agriculture-2149564.html
#
# INFO:collecteDeDonnees_09-08-21:URL : https://france3-regions.francetvinfo.fr/occitanie/herault/montpellier/ce-milliard-d-euros-ne-suffira-pas-la-reaction-dans-l-herault-au-plan-gel-du-gouvernement-pour-l-agriculture-2149564.html
#
# Le document existe déjà.
#
# INFO:collecteDeDonnees_09-08-21:Le document existe déjà.
#
# URL : https://www.herault.gouv.fr/content/download/9877/54982/file/8_DGEAF_PlaineMontpellieraineEtLunelloise.pdf
#
# INFO:collecteDeDonnees_09-08-21:URL : https://www
html
#
# INFO:collecteDeDonnees_09-08-21:URL : https://objectif-languedoc-roussillon.latribune.fr/decideurs/2017-04-13/un-heraultais-elu-numero-2-de-la-fnsea.html
# HTTP Error 403: Forbidden
# Document sauvegardé.
# INFO:collecteDeDonnees_09-08-21:Document sauvegardé.
# Document web converti en texte brut.
# INFO:collecteDeDonnees_09-08-21:Document web converti en texte brut.
# Texte nettoyé.
#
# INFO:collecteDeDonnees_09-08-21:Texte nettoyé.
#
# Document inséré dans l'inventaire.
#
# INFO:collecteDeDonnees_09-08-21:Document inséré dans l'inventaire.
#
# URL : https://journals.openedition.org/economierurale/856
#
# INFO:collecteDeDonnees_09-08-21:URL : https://journals.openedition.org/economierurale/856
#
# Document sauvegardé.
# INFO:collecteDeDonnees_09-08-21:Document sauvegardé.
# Document web converti en texte brut.
# INFO:collecteDeDonnees_09-08-21:Document web converti en texte brut.
# Texte nettoyé.
#
# INFO:collecteDeDonnees_09-08-21:Texte nettoyé.
#
# Document inséré dans l'inventaire.
#
# INFO:collecteDeDonnees_09-08-21:Document inséré dans l'inventaire.
#
# ***********************************************************************
#
# INFO:collecteDeDonnees_09-08-21:***********************************************************************
#
# 09-08-2021:14h06 : Nombre limite de requete atteint. Reprise du programme : 09-08-2021:14h07
# INFO:collecteDeDonnees_09-08-21:09-08-2021:14h06 : Nombre limite de requete atteint. Reprise du programme : 09-08-2021:14h07
# Nouvelle requête : "Montpellier" AND developpement?agricole
#
# INFO:collecteDeDonnees_09-08-21:Nouvelle requête : "Montpellier" AND developpement?agricole
#
# URL : https://www.entreprendre-montpellier.com/fr/choisir-montpellier/misez-sur-lagroecologie
#
# INFO:collecteDeDonnees_09-08-21:URL : https://www.entreprendre-montpellier.com/fr/choisir-montpellier/misez-sur-lagroecologie
#
# Le document existe déjà.
#
# INFO:collecteDeDonnees_09-08-21:Le document existe déjà.
#
# URL : https://www.emagister.fr/formation_developpement_agricole_tropical_dat-ec2498348.htm
#
# INFO:collecteDeDonnees_09-08-21:URL : https://www.emagister.fr/formation_developpement_agricole_tropical_dat-ec2498348.htm
#
# Document sauvegardé.
# INFO:collecteDeDonnees_09-08-21:Document sauvegardé.
# Document web converti en texte brut.
# INFO:collecteDeDonnees_09-08-21:Document web converti en texte brut.
# Texte nettoyé.
#
# INFO:collecteDeDonnees_09-08-21:Texte nettoyé.
#
# Document inséré dans l'inventaire.
#
# INFO:collecteDeDonnees_09-08-21:Document inséré dans l'inventaire.
#
# URL : https://www.agrorientation.com/formations/master-europeen-en-developpement-agricole-durable-13076.html
#
# INFO:collecteDeDonnees_09-08-21:URL : https://www.agrorientation.com/formations/master-europeen-en-developpement-agricole-durable-13076.html
#
# Document sauvegardé.
# INFO:collecteDeDonnees_09-08-21:Document sauvegardé.
# Document web converti en texte brut.
# INFO:collecteDeDonnees_09-08-21:Document web converti en texte brut.
# Texte nettoyé.
#
# INFO:collecteDeDonnees_09-08-21:Texte nettoyé.
#
# Document inséré dans l'inventaire.
#
# INFO:collecteDeDonnees_09-08-21:Document inséré dans l'inventaire.
#
# URL : https://diplomeo.com/bts-developpement_agricole-a-montpellier
#
# INFO:collecteDeDonnees_09-08-21:URL : https://diplomeo.com/bts-developpement_agricole-a-montpellier
#
# Document sauvegardé.
# INFO:collecteDeDonnees_09-08-21:Document sauvegardé.
# Document web converti en texte brut.
# INFO:collecteDeDonnees_09-08-21:Document web converti en texte brut.
# Texte nettoyé.
#
# INFO:collecteDeDonnees_09-08-21:Texte nettoyé.
#
# Document inséré dans l'inventaire.
#
# INFO:collecteDeDonnees_09-08-21:Document inséré dans l'inventaire.
#
# URL : https://formations.umontpellier.fr/fr/formations/master-XB/master-economie-KJSB6U1E/economie-du-developpement-agricole-de-l-environnement-et-de-l-alimentation-KJSD9QAM.html
#
# INFO:collecteDeDonnees_09-08-21:URL : https://formations.umontpellier.fr/fr/formations/master-XB/master-economie-KJSB6U1E/economie-du-developpement-agricole-de-l-environnement-et-de-l-alimentation-KJSD9QAM.html
#
# Document sauvegardé.
# INFO:collecteDeDonnees_09-08-21:Document sauvegardé.
# Document web converti en texte brut.
# INFO:collecteDeDonnees_09-08-21:Document web converti en texte brut.
# Texte nettoyé.
#
# INFO:collecteDeDonnees_09-08-21:Texte nettoyé.
#
# Document inséré dans l'inventaire.
#
# INFO:collecteDeDonnees_09-08-21:Document inséré dans l'inventaire.
#
# URL : http://www.agroparistech.fr/-Developpement-agricole-.html
#
# INFO:collecteDeDonnees_09-08-21:URL : http://www.agroparistech.fr/-Developpement-agricole-.html
#
# Document sauvegardé.
# INFO:collecteDeDonnees_09-08-21:Document sauvegardé.
# Document web converti en texte brut.
# INFO:collecteDeDonnees_09-08-21:Document web converti en texte brut.
# Texte nettoyé.
#
# INFO:collecteDeDonnees_09-08-21:Texte nettoyé.
#
# Document inséré dans l'inventaire.
#
# INFO:collecteDeDonnees_09-08-21:Document inséré dans l'inventaire.
#
# URL : https://m.agropolis.fr/formationthemeesdd.php
#
# INFO:collecteDeDonnees_09-08-21:URL : https://m.agropolis.fr/formationthemeesdd.php
#
# Document sauvegardé.
# INFO:collecteDeDonnees_09-08-21:Document sauvegardé.
# Document web converti en texte brut.
# INFO:collecteDeDonnees_09-08-21:Document web converti en texte brut.
# Texte nettoyé.
#
# INFO:collecteDeDonnees_09-08-21:Texte nettoyé.
#
# Document inséré dans l'inventaire.
#
# INFO:collecteDeDonnees_09-08-21:Document inséré dans l'inventaire.
#
# URL : https://www.montpellier-supagro.fr/formations/catalogue-des-formations/recherche-d-une-formation/master-economie-de-lenvironnement-des
#
# INFO:collecteDeDonnees_09-08-21:URL : https://www.montpellier-supagro.fr/formations/catalogue-des-formations/recherche-d-une-formation/master-economie-de-lenvironnement-des
#
# Document sauvegardé.
# INFO:collecteDeDonnees_09-08-21:Document sauvegardé.
# Erreur lors de la conversion en texte de la page web.
# Traceback (most recent call last):
#   File "/home/rodrique/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb", line 586, in sauvegarde_fichier_advanced
#     "        self.match_begin_end_nl = re.compile(r'^\\n+|\\n+$') # Nouvelles lignes au début et à la fin\n",
#   File "/home/rodrique/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb", line 434, in convert_html_to_txt
#     "        mapping_month = {\n",
#   File "/home/rodrique/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb", line 363, in less_html
#     "    \"\"\"\n",
#   File "/home/rodrique/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb", line 339, in html_date_to_isoformat
#     "        raise TimeoutException\n",
#   File "/home/rodrique/anaconda3/lib/python3.7/_strptime.py", line 571, in _strptime_time
#     tt = _strptime(data_string, format)[0]
#   File "/home/rodrique/anaconda3/lib/python3.7/_strptime.py", line 326, in _strptime
#     raise TypeError(msg.format(index, type(arg)))
# TypeError: strptime() argument 0 must be str, not <class 'datetime.datetime'>
# ERROR:collecteDeDonnees_09-08-21:Erreur lors de la conversion en texte de la page web.
# Traceback (most recent call last):
#   File "/home/rodrique/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb", line 586, in sauvegarde_fichier_advanced
#     "        self.match_begin_end_nl = re.compile(r'^\\n+|\\n+$') # Nouvelles lignes au début et à la fin\n",
#   File "/home/rodrique/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb", line 434, in convert_html_to_txt
#     "        mapping_month = {\n",
#   File "/home/rodrique/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb", line 363, in less_html
#     "    \"\"\"\n",
#   File "/home/rodrique/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb", line 339, in html_date_to_isoformat
#     "        raise TimeoutException\n",
#   File "/home/rodrique/anaconda3/lib/python3.7/_strptime.py", line 571, in _strptime_time
#     tt = _strptime(data_string, format)[0]
#   File "/home/rodrique/anaconda3/lib/python3.7/_strptime.py", line 326, in _strptime
#     raise TypeError(msg.format(index, type(arg)))
# TypeError: strptime() argument 0 must be str, not <class 'datetime.datetime'>
# URL : http://www.montpellier-supagro.fr/formations/catalogue-des-formations/recherche-d-une-formation/option-ressources-systemes-agricoles
#
# INFO:collecteDeDonnees_09-08-21:URL : http://www.montpellier-supagro.fr/formations/catalogue-des-formations/recherche-d-une-formation/option-ressources-systemes-agricoles
# Le document existe déjà.
#
# INFO:collecteDeDonnees_09-08-21:Le document existe déjà.
#
# URL : https://www.cirad.fr/
#
# INFO:collecteDeDonnees_09-08-21:URL : https://www.cirad.fr/
#
# Le document existe déjà.
#
# INFO:collecteDeDonnees_09-08-21:Le document existe déjà.
#
# ***********************************************************************
#
# INFO:collecteDeDonnees_09-08-21:***********************************************************************
#
# 09-08-2021:14h07 : Nombre limite de requete atteint. Reprise du programme : 09-08-2021:14h08
# INFO:collecteDeDonnees_09-08-21:09-08-2021:14h07 : Nombre limite de requete atteint. Reprise du programme : 09-08-2021:14h08
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-be131f575bec> in <module>
#       7 # mgdb,mgcol = 'inventaire_medo', 'agriculture_demo' # parameters to be set initially
#       8 #advanced_scraper(spatial_extent,voc_concept)
# ----> 9 advanced_scraper(spatial_extent,voc_concept)
#
# ~/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb in advanced_scraper(spatial_extent, voc_concept, site)
#     761     "        #print(link)\n",
#     762     "        link_href = link.get('href')\n",
# --> 763     "        if \"url?q=\" in link_href:# and not \"webcache\" in link_href:\n",
#     764     "            # print (link.get('href').split(\"?q=\")[1].split(\"&sa=U\")[0])\n",
#     765     "            url_list.append(link.get('href').split(\"?q=\")[1].split(\"&sa=U\")[0])\n",
#
# ~/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb in recherche_web_advanced(spatial_extent, voc_concept, motscles, logger, site)
#     705     "        with open(src_file_path, \"wb\") as fichier:\n",
#     706     "            fichier.write(read_buffer)\n",
# --> 707     "            logger.info(\"Document sauvegardé.\")\n",
#     708     "\n",
#     709     "        # On détecte le type du document source pour utiliser la conversion adaptée\n",
#
# ~/Bureau/Jupyter-notebook/Protocole_3M/Protocole_aidmoit/scrap_on_google_v2.ipynb in pause(logger, minutes)
#     100     "\n",
#     101     "    def debug(self, message):\n",
# --> 102     "        self.__logger__.debug(message)\n",
#     103     "\n",
#     104     "    def warning(self, message):\n",
#
# KeyboardInterrupt:

# %%
######## TO DO
# 1) Convertir directement les fichier à partir des Urls, et non après sauvegarde dans SCR_
# 2) Supprimer la sauvegarde locale
